# %% [markdown]
# # Data Cleansing - Monthly Retail and Food Services Sales from 1992 to 2020

# %% [markdown]
# ## Data import and merge into 1 DataFrame

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import math

# Set DataFrame display options to avoid truncating long data
pd.set_option('max_colwidth', 1000) # Show up to 1000 characters within each cell
pd.set_option('max_rows', 20) # Show up to 20 dataframe rows
pd.set_option('max_columns', 1000) # Show up to 1000 columns

# Managing Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the workbook containing data from 1992 to 2019 and append sheet name as a separate column
def read_excel_sheets(xls_path):
    # Read all sheets of an Excel workbook and return a single DataFrame
    print(f'Loading {xls_path} into pandas')
    xl = pd.ExcelFile(xls_path)
    df = pd.DataFrame()
    columns = None
    for idx, name in enumerate(xl.sheet_names):
        print(f'Reading sheet #{idx}: {name}')
        sheet = xl.parse(name)
        if idx == 0:
            # Save column names from the first sheet to match for append
            columns = sheet.columns
        sheet.columns = columns
        # Add sheet name as column
        sheet['sheet'] = name.split(" ")[-1]
        # Assume index of existing data frame when appended
        df = df.append(sheet, ignore_index = True)
    return df

# %%
data = read_excel_sheets('C:/Users/Lenovo/Downloads/DataCleansing/mrtssales92-2019.xls')
# Out:
# Loading C:/Users/Lenovo/Downloads/DataCleansing/mrtssales92-2019.xls into pandas
# Reading sheet #0: 2019
# Reading sheet #1: 2018
# Reading sheet #2: 2017
# Reading sheet #3: 2016
# Reading sheet #4: 2015
# Reading sheet #5: 2014
# Reading sheet #6: 2013
# Reading sheet #7: 2012
# Reading sheet #8: 2011
# Reading sheet #9: 2010
# Reading sheet #10: 2009
# Reading sheet #11: 2008
# Reading sheet #12: 2007
# Reading sheet #13: 2006
# Reading sheet #14: 2005
# Reading sheet #15: 2004
# Reading sheet #16: 2003
# Reading sheet #17: 2002
# Reading sheet #18: 2001
# Reading sheet #19: 2000
# Reading sheet #20: 1999
# Reading sheet #21: 1998
# Reading sheet #22: 1997
# Reading sheet #23: 1996
# Reading sheet #24: 1995
# Reading sheet #25: 1994
# Reading sheet #26: 1993
# Reading sheet #27: 1992

# %%
# Rename columns to standardised names
data = data.rename(columns = {'Estimates of Monthly Retail and Food Services Sales by Kind of Business: 2019':'NAICS Code',
                'Unnamed: 1':'Kind of Business', 'Unnamed: 2':'January', 'Unnamed: 3':'February', 'Unnamed: 4':'March', 'Unnamed: 5':'April',
                'Unnamed: 6':'May', 'Unnamed: 7':'June', 'Unnamed: 8':'July', 'Unnamed: 9':'August', 'Unnamed: 10': 'September',
                'Unnamed: 11':'October', 'Unnamed: 12':'November', 'Unnamed: 13':'December', 'Unnamed: 14':'Total', 'sheet':'Year'})
data = data.drop(columns = 'Total')
data.shape
# Out:
# (3247, 15)

# %%
# Data for 2020 has a slight different tabular format and will be processed separately before appending with other data
df_2020 = pd.read_excel('C:/Users/Lenovo/Downloads/DataCleansing/mrtssales2020.xls', sheet_name = '2020')
df_2020.columns
# Out:
# Index(['Estimates of Monthly Retail and Food Services Sales by Kind of Business: 2020',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
# Rename columns to standardised names
df_2020 = df_2020.rename(columns = {'Estimates of Monthly Retail and Food Services Sales by Kind of Business: 2020':'NAICS Code',
                'Unnamed: 1':'Kind of Business', 'Unnamed: 2':'January', 'Unnamed: 3':'February', 'Unnamed: 4':'March', 'Unnamed: 5':'April',
                'Unnamed: 6':'May', 'Unnamed: 7':'June', 'Unnamed: 8':'July', 'Unnamed: 9':'August', 'Unnamed: 10': 'September',
                'Unnamed: 11':'CY CUM', 'Unnamed: 12':'PY CUM'})

# Align tabular structure to be consistent with data from 1992 to 2019 
df_2020 = df_2020.drop(columns =['CY CUM','PY CUM'])
df_2020['Year'] = '2020'

df_2020.shape
# Out:
# (120, 12)

# %%
# Append both dataset together
data = pd.concat([data, df_2020], ignore_index = True, sort = False)

# %%
data.shape
# Out:
# (3367, 15)

# %% [markdown]
# ## Remove redundant rows & enrich categorical data

# %%
data = data[data['Kind of Business'].notna()]
data = data[data['Kind of Business'] != 'Kind of Business']
data.head(4000)
# Out:
#      NAICS Code  \
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# ...         ...
# 3351        453
# 3352        454
# 3353       4541
# 3354      45431
# 3355        722
#
#                                                                        Kind of Business  \
# 4                                                                          NOT ADJUSTED
# 5                                                 Retail and food services sales, total
# 6                           Retail sales and food services excl motor vehicle and parts
# 7                                 Retail sales and food services excl gasoline stations
# 8     Retail sales and food services excl motor vehicle and parts and gasoline stations
# ...                                                                                 ...
# 3351                                                     Miscellaneous stores retailers
# 3352                                                                 Nonstore retailers
# 3353                                          Electronic shopping and mail order houses
# 3354                                                                       Fuel dealers
# 3355                                                  Food services and drinking places
#
#      January February   March   April     May    June    July  August  \
# 4        NaN      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5     458089   443708  515694  509413  547130  518273  532103  545247
# 6     370975   354699  405849  406257  435358  413530  422834  430588
# 7     422675   409159  474734  466269  500912  474450  486653  500204
# 8     335561   320150  364889  363113  389140  369707  377384  385545
# ...      ...      ...     ...     ...     ...     ...     ...     ...
# 3351   11984    11877   10230    7591    9091   11088   11548   11712
# 3352   68101    68924   72365   79143   85256   82900   83201   87008
# 3353   60985    61620   65332   73479   79351   76398   75767   79452
# 3354    2096     2107    1974    1937    2017    2009    2028    2038
# 3355   65554    65359   45728   30032   39430   50139   52224   54406
#
#      September October November December  Year
# 4          NaN     NaN      NaN      NaN  2019
# 5       496074  525539   535352   591380  2019
# 6       396537  421738   434251   487917  2019
# 7       454138  481937   494622   551177  2019
# 8       354601  378136   393521   447714  2019
# ...        ...     ...      ...      ...   ...
# 3351     11836     NaN      NaN      NaN  2020
# 3352     85508     NaN      NaN      NaN  2020
# 3353     77884     NaN      NaN      NaN  2020
# 3354      2098     NaN      NaN      NaN  2020
# 3355     55704     NaN      NaN      NaN  2020
#
# [3045 rows x 15 columns]

# %%
data = data.reset_index(drop=True)

# %%
# Add a column to differentiate between Adjusted Values and Unadjusted Values
data['Not Adjusted/ Adjusted'] = np.nan

data.loc[data['Kind of Business'] == 'NOT ADJUSTED', 'Not Adjusted/ Adjusted'] = 'Not Adjusted'
data.loc[data['Kind of Business'] == 'ADJUSTED(2)', 'Not Adjusted/ Adjusted'] = 'Adjusted'
data['Not Adjusted/ Adjusted'] = data['Not Adjusted/ Adjusted'].fillna(method = 'ffill')

data.head(50)
# Out:
#    NAICS Code  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 45     451211
# 46        452
# 47       4521
# 48     452111
# 49     452112
#
#                                                                      Kind of Business  \
# 0                                                                        NOT ADJUSTED
# 1                                               Retail and food services sales, total
# 2                         Retail sales and food services excl motor vehicle and parts
# 3                               Retail sales and food services excl gasoline stations
# 4   Retail sales and food services excl motor vehicle and parts and gasoline stations
# ..                                                                                ...
# 45                                                                        Book stores
# 46                                                         General merchandise stores
# 47                                                                  Department stores
# 48                                Department stores(excl. discount department stores)
# 49                                                              Discount dept. stores
#
#    January February   March   April     May    June    July  August September  \
# 0      NaN      NaN     NaN     NaN     NaN     NaN     NaN     NaN       NaN
# 1   458089   443708  515694  509413  547130  518273  532103  545247    496074
# 2   370975   354699  405849  406257  435358  413530  422834  430588    396537
# 3   422675   409159  474734  466269  500912  474450  486653  500204    454138
# 4   335561   320150  364889  363113  389140  369707  377384  385545    354601
# ..     ...      ...     ...     ...     ...     ...     ...     ...       ...
# 45    1004      569     587     631     675     594     572    1088       842
# 46   51557    50513   58619   56815   60695   58727   58487   61460     54515
# 47    8657     9142   10645   10456   11299   10625   10630   11550      9762
# 48    2464     2803    3263    3285    3488    3199    3130    3253      3045
# 49    6193     6339    7382    7171    7811    7426    7500    8297      6717
#
#    October November December  Year Not Adjusted/ Adjusted
# 0      NaN      NaN      NaN  2019           Not Adjusted
# 1   525539   535352   591380  2019           Not Adjusted
# 2   421738   434251   487917  2019           Not Adjusted
# 3   481937   494622   551177  2019           Not Adjusted
# 4   378136   393521   447714  2019           Not Adjusted
# ..     ...      ...      ...   ...                    ...
# 45     627      618     1037  2019           Not Adjusted
# 46   58560    66027    77648  2019           Not Adjusted
# 47   10456    13401    18403  2019           Not Adjusted
# 48    3109     4390     6561  2019           Not Adjusted
# 49    7347     9011    11842  2019           Not Adjusted
#
# [50 rows x 16 columns]

# %%
# Remove empty rows without any monthly value
data = data[data['January'].notna()]
data.head(100)
# Out:
#     NAICS Code  \
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ..         ...
# 97        4529
# 98       45291
# 99       45299
# 100        453
# 101        454
#
#                                                                       Kind of Business  \
# 1                                                Retail and food services sales, total
# 2                          Retail sales and food services excl motor vehicle and parts
# 3                                Retail sales and food services excl gasoline stations
# 4    Retail sales and food services excl motor vehicle and parts and gasoline stations
# 5                                                                  Retail sales, total
# ..                                                                                 ...
# 97                                                    Other general merchandise stores
# 98                                                     Warehouse clubs and superstores
# 99                                                   All other gen. merchandise stores
# 100                                                     Miscellaneous stores retailers
# 101                                                                 Nonstore retailers
#
#     January February   March   April     May    June    July  August  \
# 1    458089   443708  515694  509413  547130  518273  532103  545247
# 2    370975   354699  405849  406257  435358  413530  422834  430588
# 3    422675   409159  474734  466269  500912  474450  486653  500204
# 4    335561   320150  364889  363113  389140  369707  377384  385545
# 5    401341   386840  449507  445959  479466  452242  466160  477537
# ..      ...      ...     ...     ...     ...     ...     ...     ...
# 97    47638    47104   48029   48225   48090   48268   48516   48422
# 98    40775    40387   41159   41282   41179   41364   41596   41520
# 99     6863     6717    6870    6943    6911    6904    6920    6902
# 100   10616    10650   10825   11083   11159   11269   11224   11459
# 101   62884    63494   63306   64511   66089   67026   67356   67887
#
#     September October November December  Year Not Adjusted/ Adjusted
# 1      496074  525539   535352   591380  2019           Not Adjusted
# 2      396537  421738   434251   487917  2019           Not Adjusted
# 3      454138  481937   494622   551177  2019           Not Adjusted
# 4      354601  378136   393521   447714  2019           Not Adjusted
# 5      433299  460534   473026   526295  2019           Not Adjusted
# ..        ...     ...      ...      ...   ...                    ...
# 97      48285   48620    48509    48641  2019               Adjusted
# 98      41433   41760    41635    41823  2019               Adjusted
# 99       6852    6860     6874     6818  2019               Adjusted
# 100     11449   11533    11652    11485  2019               Adjusted
# 101     67667   68297    67675    67493  2019               Adjusted
#
# [100 rows x 16 columns]

# %%
# Remove subtotal rows without any NAICS Code
data = data[data['NAICS Code'].notna()]
data.head(100)
# Out:
#     NAICS Code                                         Kind of Business  \
# 8          441                          Motor vehicle and parts dealers
# 9    4411,4412               Automobile and other motor vehicle dealers
# 10        4411                                       Automobile dealers
# 11       44111                                          New car dealers
# 12       44112                                         Used car dealers
# ..         ...                                                      ...
# 119    442,443  Furniture, home furn, electronics, and appliance stores
# 120        442                    Furniture and home furnishings stores
# 121       4421                                         Furniture stores
# 122       4422                                  Home furnishings stores
# 123      44221                                    Floor covering stores
#
#     January February   March   April     May    June    July  August  \
# 8     87114    89009  109845  103156  111772  104743  109269  114659
# 9     80026    82022  101593   95035  103357   96728  100916  106073
# 10    75271    76634   93879   86774   94030   87931   92447   98149
# 11    66443    66959   82023   76429   83481   77853   82192   87792
# 12     8828     9675   11856   10345   10549   10078   10255   10357
# ..      ...      ...     ...     ...     ...     ...     ...     ...
# 119   16467    15935   18084   16467   17799   17713   17563   18545
# 120    8686     8504   10016    9205    9949    9751    9740   10209
# 121    4597     4677    5524    4890    5254    5269    5159    5396
# 122    4089     3827    4492    4315    4695    4482    4581    4813
# 123     (S)      (S)     (S)     (S)     (S)     (S)     (S)     (S)
#
#     September October November December  Year Not Adjusted/ Adjusted
# 8       99537  103801   101101   103463  2019           Not Adjusted
# 9       91783   95254    93242    96073  2019           Not Adjusted
# 10      85390   89148    87851    91114  2019           Not Adjusted
# 11      75986   79452    78496    82445  2019           Not Adjusted
# 12       9404    9696     9355     8669  2019           Not Adjusted
# ..        ...     ...      ...      ...   ...                    ...
# 119     17312   17548    20868    22799  2018           Not Adjusted
# 120      9573    9758    10579    10925  2018           Not Adjusted
# 121      5225    5027     5314     5229  2018           Not Adjusted
# 122      4348    4731     5265     5696  2018           Not Adjusted
# 123       (S)     (S)      (S)      (S)  2018           Not Adjusted
#
# [100 rows x 16 columns]

# %% [markdown]
# Upon analysing the dataset, we can observe that there are many level of aggregation based on the North American Industry Classification System (NAICS). In the below section, we will add some flag to classify the level of aggregation to avoid double counting. We will be using the below description for our flag.
# - L0: 441, 442, 443 and so on
# - L1: sub-class of L0 (for example, 4411, 4413)
# - L2: sub-class of L1 (for example, 44111, 44112)
# - L3: sub-class of L2 (for example, 443141, 443142)
# - A: for rows which include the sum of value across multiple NAICS code. These rows will be removed from the dataset to avoid double counting.

# %%
# Calculate length of NAICS Code column to determine the appropriate flag
data['NAICS Code Length'] = data['NAICS Code'].astype(str).str.len()
data.head()
# Out:
#    NAICS Code                            Kind of Business January February  \
# 8         441             Motor vehicle and parts dealers   87114    89009
# 9   4411,4412  Automobile and other motor vehicle dealers   80026    82022
# 10       4411                          Automobile dealers   75271    76634
# 11      44111                             New car dealers   66443    66959
# 12      44112                            Used car dealers    8828     9675
#
#      March   April     May    June    July  August September October November  \
# 8   109845  103156  111772  104743  109269  114659     99537  103801   101101
# 9   101593   95035  103357   96728  100916  106073     91783   95254    93242
# 10   93879   86774   94030   87931   92447   98149     85390   89148    87851
# 11   82023   76429   83481   77853   82192   87792     75986   79452    78496
# 12   11856   10345   10549   10078   10255   10357      9404    9696     9355
#
#    December  Year Not Adjusted/ Adjusted  NAICS Code Length
# 8    103463  2019           Not Adjusted                  3
# 9     96073  2019           Not Adjusted                  9
# 10    91114  2019           Not Adjusted                  4
# 11    82445  2019           Not Adjusted                  5
# 12     8669  2019           Not Adjusted                  5

# %%
# Implement the flag & remove rows containing sum of values across multiple NAICS code
conditions = [(data['NAICS Code Length'] == 3), 
              (data['NAICS Code Length'] == 4), 
              (data['NAICS Code Length'] == 5), 
              (data['NAICS Code Length'] == 6), 
              (data['NAICS Code Length'] > 6)]

values = ['L0', 'L1', 'L2', 'L3', 'A']

data['Flag'] = np.select(conditions, values)

data = data[data['Flag']!='A']

data.head()
# Out:
#    NAICS Code                         Kind of Business January February  \
# 8         441          Motor vehicle and parts dealers   87114    89009
# 10       4411                       Automobile dealers   75271    76634
# 11      44111                          New car dealers   66443    66959
# 12      44112                         Used car dealers    8828     9675
# 13       4413  Automotive parts, acc., and tire stores    7088     6987
#
#      March   April     May    June    July  August September October November  \
# 8   109845  103156  111772  104743  109269  114659     99537  103801   101101
# 10   93879   86774   94030   87931   92447   98149     85390   89148    87851
# 11   82023   76429   83481   77853   82192   87792     75986   79452    78496
# 12   11856   10345   10549   10078   10255   10357      9404    9696     9355
# 13    8252    8121    8415    8015    8353    8586      7754    8547     7859
#
#    December  Year Not Adjusted/ Adjusted  NAICS Code Length Flag
# 8    103463  2019           Not Adjusted                  3   L0
# 10    91114  2019           Not Adjusted                  4   L1
# 11    82445  2019           Not Adjusted                  5   L2
# 12     8669  2019           Not Adjusted                  5   L2
# 13     7390  2019           Not Adjusted                  4   L1

# %% [markdown]
# To make it easier to perform aggregation later across different codes, we will also be adding an additional column to indicate the Parent NAICS Code. For example, the parent NAICS Code of 4411 is 441. Rows with the same Parent NAICS Code can be summed together to represent the total of the corresponding parent NAICS Code.

# %%
# Add the Parent NAICS Code 
data['Parent NAICS Code'] = data['NAICS Code'].astype(str).str[:-1]

data.head()
# Out:
#    NAICS Code                         Kind of Business January February  \
# 8         441          Motor vehicle and parts dealers   87114    89009
# 10       4411                       Automobile dealers   75271    76634
# 11      44111                          New car dealers   66443    66959
# 12      44112                         Used car dealers    8828     9675
# 13       4413  Automotive parts, acc., and tire stores    7088     6987
#
#      March   April     May    June    July  August September October November  \
# 8   109845  103156  111772  104743  109269  114659     99537  103801   101101
# 10   93879   86774   94030   87931   92447   98149     85390   89148    87851
# 11   82023   76429   83481   77853   82192   87792     75986   79452    78496
# 12   11856   10345   10549   10078   10255   10357      9404    9696     9355
# 13    8252    8121    8415    8015    8353    8586      7754    8547     7859
#
#    December  Year Not Adjusted/ Adjusted  NAICS Code Length Flag  \
# 8    103463  2019           Not Adjusted                  3   L0
# 10    91114  2019           Not Adjusted                  4   L1
# 11    82445  2019           Not Adjusted                  5   L2
# 12     8669  2019           Not Adjusted                  5   L2
# 13     7390  2019           Not Adjusted                  4   L1
#
#    Parent NAICS Code
# 8                 44
# 10               441
# 11              4411
# 12              4411
# 13               441

# %% [markdown]
# ## Correct missing numerical values

# %%
# Replace missing numerical values (denoted with the string '(S)') with 0
data = data.replace(r'(S)', 0)

# Replace missing numerical values (denoted with the string '(NA)') with 0
data = data.replace(r'(NA)', 0)

# %% [markdown]
# ## Unpivot and export clean data to Excel file

# %%
data.columns
# Out:
# Index(['NAICS Code', 'Kind of Business', 'January', 'February', 'March',
#        'April', 'May', 'June', 'July', 'August', 'September', 'October',
#        'November', 'December', 'Year', 'Not Adjusted/ Adjusted',
#        'NAICS Code Length', 'Flag', 'Parent NAICS Code'],
#       dtype='object')

# %%
# Unpivot data
data_unpivot = pd.melt(data,id_vars = ['Parent NAICS Code', 'NAICS Code', 'Flag', 'Kind of Business',
                                       'Not Adjusted/ Adjusted', 'Year'], 
                       value_vars = ['January', 'February', 'March', 'April', 'May', 'June', 
                                     'July', 'August', 'September', 'October','November', 'December'], 
                       var_name = 'Month',
                       value_name = 'Monthly Sales ($ millions)')
data_unpivot.head()
# Out:
#   Parent NAICS Code NAICS Code Flag                         Kind of Business  \
# 0                44        441   L0          Motor vehicle and parts dealers
# 1               441       4411   L1                       Automobile dealers
# 2              4411      44111   L2                          New car dealers
# 3              4411      44112   L2                         Used car dealers
# 4               441       4413   L1  Automotive parts, acc., and tire stores
#
#   Not Adjusted/ Adjusted  Year    Month  Monthly Sales ($ millions)
# 0           Not Adjusted  2019  January                     87114.0
# 1           Not Adjusted  2019  January                     75271.0
# 2           Not Adjusted  2019  January                     66443.0
# 3           Not Adjusted  2019  January                      8828.0
# 4           Not Adjusted  2019  January                      7088.0

# %%
# Drop rows related to year 2020 from October to December because there is no monthly sales value recorded yet
data_unpivot = data_unpivot.dropna(subset=['Monthly Sales ($ millions)'])

# %%
# Write to Excel file
data_unpivot.to_excel('mrtssales.xlsx', sheet_name = 'data', index = False)
